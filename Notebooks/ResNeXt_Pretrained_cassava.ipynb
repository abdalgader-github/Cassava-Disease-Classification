# %% [markdown]
# <a href="https://colab.research.google.com/github/gdoorash/Cassava-Disease-Classification/blob/gdoora_side/Notebooks/ResNeXt_Pretrained_cassava.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ResNet_Pretrained Architecture**

# %%
import numpy
import torch 
import torchvision 
import os
import matplotlib.pyplot as plt
import random 
import pdb
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, sampler
import imageio
import PIL
from IPython import display
from torchvision import datasets
import torch.nn as nn

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/My Drive/Colab Notebooks/Data/Cassava_t_v_t.zip";

# %%
# %matplotlib inline

def show(img):
    """Show PyTorch tensor img as an image in matplotlib."""
    npimg = img.cpu().detach().numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)), interpolation='nearest')
    plt.grid(False)
    plt.gca().axis('off')

def display_thumb(img):
  display.display(transforms.Resize(128)(img))

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## **Prepare the dataset** (balancing, spiliting, data augmentation, ..etc)

# %%
# Load Cassava dataset
traindata_folder_path = '/content/ammi-2020-convnets/train/train'
valdata_folder_path = '/content/ammi-2020-convnets/train/validation'
testdata_folder_path = '/content/ammi-2020-convnets/test/test'


# load the extra data for self-supervie (Autoencodrer)..
extra_folder_path = '/content/ammi-2020-convnets/extraimages'

# %%
# compute the mean and standard deviation of the all images (train, val, test)

# %%
# torch_example = torch.randn((100, 3, 50, 50))
# torch_example_mean = torch_example.mean(axis=(0,2,3))
# torch_example_mean
# # torch_example_mean2 = torch_example.mean(axis=(2,3))
# print('per batch = {0}'.format(torch_example_mean2.shape))
# torch_example_mean2 = torch_example_mean2.mean(axis=(0))
# print('per batch_and h and w = {0}'.format(torch_example_mean2.shape))

# %%
# tf = transforms.Compose([
#     transforms.Resize((256, 256)),
#     transforms.ToTensor(),
# ])
# cassava_train = datasets.ImageFolder(traindata_folder_path, transform=tf)
# trainloader = torch.utils.data.DataLoader(cassava_train, batch_size=700, shuffle=True, num_workers=8)

# %%
# # compute the mean and standard deviation of the images ...
# run_mean = torch.zeros(3)
# for i, (batch,_) in enumerate(trainloader):
#   curr_mean = batch.mean(axis=(0,2,3))
#   run_mean = ((run_mean*i) + curr_mean)/(i+1)

# %%
# run_mean

# %%
# for imgs,_ in trainloader:
#     print(imgs.std((0,2,3)))
#     break

# %%
######################### Transformations of images #################################################


inference_transform = transforms.Compose([
    transforms.Resize((500, 500)),
    transforms.CenterCrop(256),
    # transforms.RandomGrayscale(p=0.3),
    transforms.RandomHorizontalFlip(p=0.4),
    transforms.RandomVerticalFlip(p=0.4),
    transforms.RandomRotation((-10,+10)),
    # transforms.ColorJitter((0.6, 1.8), (0, 1.5),(0.8,2.3)),
    transforms.ToTensor(),
    transforms.Normalize([0.4479, 0.4963, 0.3217], [0.2074, 0.2087, 0.1896])
   
])

# For visualization purposes we'll create a separate transform that operates in image space.
inference_transform_show = transforms.Compose([
    transforms.Resize(500),
    transforms.CenterCrop(256),
])


########################################   Transform and put the data into Dataset object #########################################################################

transformed_cassava_trian = datasets.ImageFolder(traindata_folder_path, transform=inference_transform)
transformed_cassava_validation = datasets.ImageFolder( valdata_folder_path, transform=inference_transform) 
transformed_cassava_test = datasets.ImageFolder(testdata_folder_path,  transform=inference_transform)

##########################################  Load the data into DataLoader #########################################################
transformed_cassava_trainloader = torch.utils.data.DataLoader(transformed_cassava_trian, batch_size=32, shuffle=True, num_workers=8)
transformed_cassava_valloader = torch.utils.data.DataLoader(transformed_cassava_validation, batch_size=8, shuffle=False, num_workers=8)
transformed_cassava_testloader = torch.utils.data.DataLoader(transformed_cassava_test, batch_size=32, shuffle=False, num_workers=8)




########## Extra data set loading ##########################################################################

transformed_cassava_extra = datasets.ImageFolder(extra_folder_path, transform=inference_transform,)
transformed_cassava_extraloader = torch.utils.data.DataLoader(transformed_cassava_extra , batch_size=32, shuffle=True, num_workers=8)

# %%
# # 
# transformed_cassava_extra[66][0]
# # type(transforms.RandomGrayscale(p=0.5))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE5F8001EB8>

# %% [markdown]
# ## **Basic function for training & testing**

# %%
def accuracy(output, target, topk=(1,)):
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
train_losses = []
valid_losses = []

def train (model, criterion, train_dataloader, valid_dataloader, optimizer, num_epochs):
    
    
    
    # move the model to GPU
    model.to(device)
    
    




    print("# Start training...")
    for epoch in range(num_epochs):
      
      train_loss = 0
      train_n_iter = 0
      tcorrect = 0

      # put the model in train mode
      model.train()
     
      for batch_index, (batch, target) in enumerate(train_dataloader):
          batch = batch.to(device)
          target = target.to(device)
          
          optimizer.zero_grad()
          
          # Forward step 
          output = model(batch)
          loss = criterion(output.to(device), target)
          
          # Backward step 
          loss.backward()
          #gradient step
          optimizer.step()
          

          # compute the accuracy
          prediction = output.argmax(dim=1, keepdim=True)
          tcorrect += prediction.cpu().eq(target.cpu().view_as(prediction)).sum().item()

          # avarge of loss
          train_loss += loss.item()
          train_n_iter += 1

      valid_loss = 0
      valid_n_iter = 0
      vcorrect = 0

      model.eval()

      #iterate over valid data..
      for images, labels in transformed_cassava_valloader:
        images = images.to(device)
        labels = labels.to(device)

        #forward
        outputs = model(images)
        loss = criterion(outputs, labels)

        # compute accuracy
        prediction = outputs.argmax(dim=1, keepdim=True)
        vcorrect += prediction.cpu().eq(labels.cpu().view_as(prediction)).sum().item()
        
        # loss and accuracy
        valid_loss += loss.item()
        valid_n_iter += 1

      
      train_losses.append(train_loss/train_n_iter)
      valid_losses.append(valid_loss/valid_n_iter)
   
      train_percent = 100. * tcorrect / len(train_dataloader.dataset)
      valid_percent = 100. * vcorrect / len(valid_dataloader.dataset) 

      # Print out progress the end of epoch.
      print('\nEpoch:{}/{} \tTrain Loss: {:.4f} \tValid Loss: {:.4f} -------- Train Accuracy: {} \tValid Accuracy: {}\tDF: {}'.format(
         epoch + 1, num_epochs,
        train_loss/train_n_iter, valid_loss / valid_n_iter,
        train_percent, valid_percent, train_percent-valid_percent))
      

def test (model, criterion, dataloader):
    
    model.eval()
    correct = 0
    # avg_loss = 0
    with torch.no_grad():
        
        for data, target in dataloader:
             
            data = data.to(device)
            target = target.to(device)
            
            output = model(data).to(device)
            loss = criterion(output, target) 
            
            prediction = output.argmax(dim=1, keepdim=True) 
            correct += prediction.cpu().eq(target.view_as(prediction)).sum().item()
            
            # avg_loss += loss.item() 
    percent = 100. * correct / len(dataloader.dataset)
    print(f'Accuracy: {correct}/{len(dataloader.dataset)} ({percent:.0f}%)')
   
    return percent

# %% [markdown]
# ## **Model Architecture (ResNet)**

# %%
# define the per-trained model...
# full_resnet_model = torchvision.models.(pretrained=True)
full_resnet_model = torch.hub.load('pytorch/vision:v0.6.0', 'resnext50_32x4d', pretrained=True)
# full_resnet_model
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.6.0.zip" to /root/.cache/torch/hub/v0.6.0.zip
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to /root/.cache/torch/hub/checkpoints/resnext50_32x4d-7cdf4587.pth
# HBox(children=(IntProgress(value=0, max=100441675), HTML(value='')))

# %%
class ModelResNet(nn.Module):

  def __init__(self):
    super(ModelResNet, self).__init__()
    self.res_mod = nn.Sequential(*list(full_resnet_model.children())[:-5])
    self.maxpool = nn.MaxPool2d(3)
    self.avgpool = nn.AdaptiveAvgPool2d(1)
   
    self.fc =  nn.Linear(256*21**2, 5)
   

  def forward(self, x):
      x = self.res_mod(x)
      x = self.maxpool(x)
      x = self.fc(x.view(x.size(0), -1))
      
      return x

# %%
# Model Architectuer..
model = ModelResNet()
# model

# %%
x = torch.randn((32, 3, 256, 256))
model(x).shape
# Out:
# torch.Size([32, 5])

# %% [markdown]
# ## **Run the Model**  (checkpoint save and load, optimizer,...)

# %%
# Create checkpoint ...
path = "/content/gdrive/My Drive/Colab Notebooks/model_data_checkpoints/ResNet/resnetcp_1.pt"
torch.save(model.state_dict(), path)

# %%
# load the checkpoint...
# model = model.load_state_dict(torch.load("/content/gdrive/My Drive/Colab Notebooks/model_data_checkpoints/ResNet/resnetcp_1.pt"))
# model

# %%
if device == 'cuda':
    model = model.cuda()
num_epochs = 100   
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=0.001)
train(model, nn.CrossEntropyLoss(), transformed_cassava_trainloader,  transformed_cassava_valloader, optimizer, num_epochs)
# Out:
# # Start training...
#
# Epoch:1/100 	Train Loss: 1.3514 	Valid Loss: 2.0677 -------- Train Accuracy: 55.84318139185894 	Valid Accuracy: 35.69230769230769	DF: 20.150873699551248
#
# Epoch:2/100 	Train Loss: 0.9994 	Valid Loss: 1.2867 -------- Train Accuracy: 64.07803413993622 	Valid Accuracy: 46.76923076923077	DF: 17.308803370705455
#
# Epoch:3/100 	Train Loss: 0.8568 	Valid Loss: 0.8546 -------- Train Accuracy: 68.61752016507222 	Valid Accuracy: 68.3076923076923	DF: 0.3098278573799149
#
# Epoch:4/100 	Train Loss: 0.7892 	Valid Loss: 1.1129 -------- Train Accuracy: 71.71262427311949 	Valid Accuracy: 56.0	DF: 15.712624273119488
#
# Epoch:5/100 	Train Loss: 0.7491 	Valid Loss: 1.0537 -------- Train Accuracy: 74.22622397298818 	Valid Accuracy: 58.15384615384615	DF: 16.072377819142027
#
# Epoch:6/100 	Train Loss: 0.6846 	Valid Loss: 0.7292 -------- Train Accuracy: 76.0082536109548 	Valid Accuracy: 71.07692307692308	DF: 4.931330534031716
#
# Epoch:7/100 	Train Loss: 0.6576 	Valid Loss: 1.0210 -------- Train Accuracy: 77.62145938848246 	Valid Accuracy: 63.07692307692308	DF: 14.544536311559384
#
# Epoch:8/100 	Train Loss: 0.6091 	Valid Loss: 0.7970 -------- Train Accuracy: 78.65316075783156 	Valid Accuracy: 70.46153846153847	DF: 8.19162229629309
#
# Epoch:9/100 	Train Loss: 0.6020 	Valid Loss: 1.0744 -------- Train Accuracy: 79.34721440630275 	Valid Accuracy: 61.84615384615385	DF: 17.501060560148908
#
# Epoch:10/100 	Train Loss: 0.5641 	Valid Loss: 0.8278 -------- Train Accuracy: 80.39767398236728 	Valid Accuracy: 68.61538461538461	DF: 11.782289366982667
#
# Epoch:11/100 	Train Loss: 0.5473 	Valid Loss: 0.7329 -------- Train Accuracy: 81.1480022509848 	Valid Accuracy: 73.84615384615384	DF: 7.301848404830963
#
# Epoch:12/100 	Train Loss: 0.5324 	Valid Loss: 0.9775 -------- Train Accuracy: 81.05421121740761 	Valid Accuracy: 65.84615384615384	DF: 15.208057371253773
#
# Epoch:13/100 	Train Loss: 0.4945 	Valid Loss: 0.8190 -------- Train Accuracy: 83.23016319639842 	Valid Accuracy: 69.53846153846153	DF: 13.691701657936889
#
# Epoch:14/100 	Train Loss: 0.5203 	Valid Loss: 0.6805 -------- Train Accuracy: 82.44231851435003 	Valid Accuracy: 76.61538461538461	DF: 5.826933898965422
#
# Epoch:15/100 	Train Loss: 0.4560 	Valid Loss: 0.8257 -------- Train Accuracy: 84.56199587319452 	Valid Accuracy: 72.92307692307692	DF: 11.6389189501176
#
# Epoch:16/100 	Train Loss: 0.4639 	Valid Loss: 1.2045 -------- Train Accuracy: 83.83042581129244 	Valid Accuracy: 60.61538461538461	DF: 23.21504119590783
#
# Epoch:17/100 	Train Loss: 0.4469 	Valid Loss: 0.9498 -------- Train Accuracy: 84.91840180078785 	Valid Accuracy: 69.23076923076923	DF: 15.687632570018621
#
# Epoch:18/100 	Train Loss: 0.4531 	Valid Loss: 1.3584 -------- Train Accuracy: 84.16807353217033 	Valid Accuracy: 60.30769230769231	DF: 23.86038122447802
#
# Epoch:19/100 	Train Loss: 0.4284 	Valid Loss: 0.6748 -------- Train Accuracy: 85.46238979553554 	Valid Accuracy: 76.92307692307692	DF: 8.539312872458623
#
# Epoch:20/100 	Train Loss: 0.4368 	Valid Loss: 0.9478 -------- Train Accuracy: 85.01219283436504 	Valid Accuracy: 70.76923076923077	DF: 14.242962065134265
#
# Epoch:21/100 	Train Loss: 0.3828 	Valid Loss: 1.0588 -------- Train Accuracy: 87.30069405364847 	Valid Accuracy: 64.92307692307692	DF: 22.37761713057155
#
# Epoch:22/100 	Train Loss: 0.3743 	Valid Loss: 0.8393 -------- Train Accuracy: 86.92552991933971 	Valid Accuracy: 72.3076923076923	DF: 14.617837611647403
#
# Epoch:23/100 	Train Loss: 0.3948 	Valid Loss: 0.8871 -------- Train Accuracy: 86.25023447758394 	Valid Accuracy: 69.53846153846153	DF: 16.71177293912241
#
# Epoch:24/100 	Train Loss: 0.3676 	Valid Loss: 0.8600 -------- Train Accuracy: 87.75089101481899 	Valid Accuracy: 71.07692307692308	DF: 16.67396793789591
#
# Epoch:25/100 	Train Loss: 0.3785 	Valid Loss: 0.9962 -------- Train Accuracy: 87.0193209529169 	Valid Accuracy: 67.07692307692308	DF: 19.94239787599382
#
# Epoch:26/100 	Train Loss: 0.3543 	Valid Loss: 0.7652 -------- Train Accuracy: 87.61958356781092 	Valid Accuracy: 71.6923076923077	DF: 15.927275875503227
#
# Epoch:27/100 	Train Loss: 0.3664 	Valid Loss: 0.7509 -------- Train Accuracy: 87.22566122678671 	Valid Accuracy: 72.61538461538461	DF: 14.6102766114021
#
# Epoch:28/100 	Train Loss: 0.3564 	Valid Loss: 0.6890 -------- Train Accuracy: 87.28193584693304 	Valid Accuracy: 75.6923076923077	DF: 11.589628154625345
#
# Epoch:29/100 	Train Loss: 0.3393 	Valid Loss: 0.9755 -------- Train Accuracy: 88.53873569686738 	Valid Accuracy: 68.0	DF: 20.538735696867377
#
# Epoch:30/100 	Train Loss: 0.3236 	Valid Loss: 0.7815 -------- Train Accuracy: 88.57625211029826 	Valid Accuracy: 75.6923076923077	DF: 12.883944417990563
#
# Epoch:31/100 	Train Loss: 0.2937 	Valid Loss: 0.6510 -------- Train Accuracy: 89.79553554680173 	Valid Accuracy: 79.6923076923077	DF: 10.103227854494037
#
# Epoch:32/100 	Train Loss: 0.3129 	Valid Loss: 0.7878 -------- Train Accuracy: 89.30782217220033 	Valid Accuracy: 74.76923076923077	DF: 14.538591402969558
#
# Epoch:33/100 	Train Loss: 0.3163 	Valid Loss: 0.7882 -------- Train Accuracy: 89.12024010504595 	Valid Accuracy: 74.46153846153847	DF: 14.658701643507484
#
# Epoch:34/100 	Train Loss: 0.3004 	Valid Loss: 0.8692 -------- Train Accuracy: 89.85181016694804 	Valid Accuracy: 70.15384615384616	DF: 19.69796401310188
#
# Epoch:35/100 	Train Loss: 0.2832 	Valid Loss: 1.1759 -------- Train Accuracy: 90.3770399549803 	Valid Accuracy: 63.69230769230769	DF: 26.68473226267261
#
# Epoch:36/100 	Train Loss: 0.2897 	Valid Loss: 0.7816 -------- Train Accuracy: 89.94560120052523 	Valid Accuracy: 73.53846153846153	DF: 16.4071396620637
#
# Epoch:37/100 	Train Loss: 0.2732 	Valid Loss: 0.7874 -------- Train Accuracy: 90.620896642281 	Valid Accuracy: 72.61538461538461	DF: 18.005512026896383
#
# Epoch:38/100 	Train Loss: 0.2440 	Valid Loss: 0.8025 -------- Train Accuracy: 91.44625773776028 	Valid Accuracy: 76.3076923076923	DF: 15.13856543006797
#
# Epoch:39/100 	Train Loss: 0.2721 	Valid Loss: 0.6209 -------- Train Accuracy: 90.45207278184206 	Valid Accuracy: 78.46153846153847	DF: 11.990534320303595
#
# Epoch:40/100 	Train Loss: 0.2413 	Valid Loss: 0.5847 -------- Train Accuracy: 92.14031138623147 	Valid Accuracy: 80.61538461538461	DF: 11.52492677084686
#
# Epoch:41/100 	Train Loss: 0.2388 	Valid Loss: 0.6817 -------- Train Accuracy: 91.84018007878447 	Valid Accuracy: 78.46153846153847	DF: 13.378641617246004
#
# Epoch:42/100 	Train Loss: 0.2565 	Valid Loss: 0.8008 -------- Train Accuracy: 90.75220408928907 	Valid Accuracy: 74.46153846153847	DF: 16.2906656277506
#
# Epoch:43/100 	Train Loss: 0.2345 	Valid Loss: 0.6850 -------- Train Accuracy: 91.89645469893078 	Valid Accuracy: 75.6923076923077	DF: 16.20414700662309
#
# Epoch:44/100 	Train Loss: 0.2446 	Valid Loss: 0.6116 -------- Train Accuracy: 91.5588069780529 	Valid Accuracy: 80.3076923076923	DF: 11.251114670360593
#
# Epoch:45/100 	Train Loss: 0.2368 	Valid Loss: 0.8948 -------- Train Accuracy: 91.65259801163009 	Valid Accuracy: 72.3076923076923	DF: 19.344905703937783
#
# Epoch:46/100 	Train Loss: 0.2485 	Valid Loss: 0.6949 -------- Train Accuracy: 91.65259801163009 	Valid Accuracy: 81.23076923076923	DF: 10.421828780860864
#
# Epoch:47/100 	Train Loss: 0.2190 	Valid Loss: 0.7028 -------- Train Accuracy: 92.57175014068655 	Valid Accuracy: 78.46153846153847	DF: 14.11021167914808
#
# Epoch:48/100 	Train Loss: 0.2318 	Valid Loss: 0.7392 -------- Train Accuracy: 91.82142187206902 	Valid Accuracy: 78.76923076923077	DF: 13.05219110283825
#
# Epoch:49/100 	Train Loss: 0.2458 	Valid Loss: 0.6472 -------- Train Accuracy: 91.46501594447571 	Valid Accuracy: 80.92307692307692	DF: 10.54193902139879
#
# Epoch:50/100 	Train Loss: 0.1959 	Valid Loss: 0.8353 -------- Train Accuracy: 93.05946351528794 	Valid Accuracy: 73.84615384615384	DF: 19.213309669134105
#
# Epoch:51/100 	Train Loss: 0.2026 	Valid Loss: 0.7649 -------- Train Accuracy: 93.30332020258864 	Valid Accuracy: 78.46153846153847	DF: 14.84178174105017
#
# Epoch:52/100 	Train Loss: 0.2043 	Valid Loss: 0.8814 -------- Train Accuracy: 93.00318889514162 	Valid Accuracy: 73.53846153846153	DF: 19.464727356680086
#
# Epoch:53/100 	Train Loss: 0.1863 	Valid Loss: 0.7452 -------- Train Accuracy: 93.75351716375914 	Valid Accuracy: 75.6923076923077	DF: 18.06120947145145
#
# Epoch:54/100 	Train Loss: 0.1798 	Valid Loss: 0.8278 -------- Train Accuracy: 93.9786156443444 	Valid Accuracy: 75.38461538461539	DF: 18.594000259729015
#
# Epoch:55/100 	Train Loss: 0.1908 	Valid Loss: 0.7757 -------- Train Accuracy: 93.24704558244233 	Valid Accuracy: 75.07692307692308	DF: 18.170122505519245
#
# Epoch:56/100 	Train Loss: 0.1671 	Valid Loss: 0.7614 -------- Train Accuracy: 94.61639467266929 	Valid Accuracy: 77.23076923076923	DF: 17.38562544190006
#
# Epoch:57/100 	Train Loss: 0.1772 	Valid Loss: 0.7903 -------- Train Accuracy: 93.95985743762897 	Valid Accuracy: 75.6923076923077	DF: 18.267549745321276
#
# Epoch:58/100 	Train Loss: 0.1657 	Valid Loss: 0.9983 -------- Train Accuracy: 94.20371412492966 	Valid Accuracy: 69.23076923076923	DF: 24.972944894160435
#
# Epoch:59/100 	Train Loss: 0.1758 	Valid Loss: 0.8577 -------- Train Accuracy: 93.86606640405178 	Valid Accuracy: 73.23076923076923	DF: 20.635297173282552
#
# Epoch:60/100 	Train Loss: 0.1694 	Valid Loss: 0.9240 -------- Train Accuracy: 94.18495591821421 	Valid Accuracy: 73.84615384615384	DF: 20.338802072060375
#
# Epoch:61/100 	Train Loss: 0.2003 	Valid Loss: 0.9718 -------- Train Accuracy: 92.94691427499531 	Valid Accuracy: 72.3076923076923	DF: 20.639221967303
#
# Epoch:62/100 	Train Loss: 0.1583 	Valid Loss: 0.8942 -------- Train Accuracy: 94.50384543237666 	Valid Accuracy: 72.61538461538461	DF: 21.88846081699205
#
# Epoch:63/100 	Train Loss: 0.1541 	Valid Loss: 0.7527 -------- Train Accuracy: 94.56012005252298 	Valid Accuracy: 80.92307692307692	DF: 13.637043129446056
#
# Epoch:64/100 	Train Loss: 0.1452 	Valid Loss: 0.9659 -------- Train Accuracy: 95.23541549427874 	Valid Accuracy: 72.0	DF: 23.23541549427874
#
# Epoch:65/100 	Train Loss: 0.1527 	Valid Loss: 1.0614 -------- Train Accuracy: 94.87900956668543 	Valid Accuracy: 71.6923076923077	DF: 23.186701874377732
#
# Epoch:66/100 	Train Loss: 0.1474 	Valid Loss: 0.8252 -------- Train Accuracy: 94.67266929281561 	Valid Accuracy: 75.07692307692308	DF: 19.595746215892532
#
# Epoch:67/100 	Train Loss: 0.1681 	Valid Loss: 0.9106 -------- Train Accuracy: 94.18495591821421 	Valid Accuracy: 74.76923076923077	DF: 19.41572514898344
#
# Epoch:68/100 	Train Loss: 0.1482 	Valid Loss: 0.9225 -------- Train Accuracy: 94.57887825923842 	Valid Accuracy: 74.15384615384616	DF: 20.425032105392262
#
# Epoch:69/100 	Train Loss: 0.1515 	Valid Loss: 0.7515 -------- Train Accuracy: 94.46632901894579 	Valid Accuracy: 82.46153846153847	DF: 12.004790557407318
#
# Epoch:70/100 	Train Loss: 0.1348 	Valid Loss: 0.8151 -------- Train Accuracy: 95.42299756143312 	Valid Accuracy: 77.23076923076923	DF: 18.192228330663895
#
# Epoch:71/100 	Train Loss: 0.1205 	Valid Loss: 0.7946 -------- Train Accuracy: 95.92946914274995 	Valid Accuracy: 77.23076923076923	DF: 18.698699911980725
#
# Epoch:72/100 	Train Loss: 0.1163 	Valid Loss: 0.9262 -------- Train Accuracy: 96.32339148377415 	Valid Accuracy: 73.84615384615384	DF: 22.477237637620306
#
# Epoch:73/100 	Train Loss: 0.1546 	Valid Loss: 0.6838 -------- Train Accuracy: 94.63515287938473 	Valid Accuracy: 78.76923076923077	DF: 15.86592211015396
#
# Epoch:74/100 	Train Loss: 0.1267 	Valid Loss: 0.7285 -------- Train Accuracy: 95.53554680172576 	Valid Accuracy: 78.76923076923077	DF: 16.766316032494984
#
# Epoch:75/100 	Train Loss: 0.1209 	Valid Loss: 0.7560 -------- Train Accuracy: 95.83567810917276 	Valid Accuracy: 78.46153846153847	DF: 17.374139647634294
#
# Epoch:76/100 	Train Loss: 0.1153 	Valid Loss: 0.8071 -------- Train Accuracy: 95.96698555618083 	Valid Accuracy: 77.23076923076923	DF: 18.736216325411604
#
# Epoch:77/100 	Train Loss: 0.1114 	Valid Loss: 0.8298 -------- Train Accuracy: 96.17332583005064 	Valid Accuracy: 78.76923076923077	DF: 17.40409506081987
#
# Epoch:78/100 	Train Loss: 0.1429 	Valid Loss: 0.7386 -------- Train Accuracy: 94.82273494653911 	Valid Accuracy: 78.15384615384616	DF: 16.668888792692954
#
# Epoch:79/100 	Train Loss: 0.1064 	Valid Loss: 0.9252 -------- Train Accuracy: 96.26711686362783 	Valid Accuracy: 74.46153846153847	DF: 21.805578402089367
#
# Epoch:80/100 	Train Loss: 0.1353 	Valid Loss: 0.8637 -------- Train Accuracy: 95.19789908084788 	Valid Accuracy: 78.46153846153847	DF: 16.73636061930941
#
# Epoch:81/100 	Train Loss: 0.1067 	Valid Loss: 0.7950 -------- Train Accuracy: 96.43594072406678 	Valid Accuracy: 76.92307692307692	DF: 19.512863800989862
#
# Epoch:82/100 	Train Loss: 0.1202 	Valid Loss: 0.8704 -------- Train Accuracy: 95.98574376289626 	Valid Accuracy: 77.23076923076923	DF: 18.754974532127036
#
# Epoch:83/100 	Train Loss: 0.0948 	Valid Loss: 0.9118 -------- Train Accuracy: 96.99868692552992 	Valid Accuracy: 73.23076923076923	DF: 23.767917694760698
#
# Epoch:84/100 	Train Loss: 0.0922 	Valid Loss: 0.8340 -------- Train Accuracy: 96.66103920465204 	Valid Accuracy: 76.92307692307692	DF: 19.737962281575122
#
# Epoch:85/100 	Train Loss: 0.1348 	Valid Loss: 0.7881 -------- Train Accuracy: 95.23541549427874 	Valid Accuracy: 79.6923076923077	DF: 15.543107801971047
#
# Epoch:86/100 	Train Loss: 0.1220 	Valid Loss: 0.7974 -------- Train Accuracy: 95.76064528231102 	Valid Accuracy: 78.15384615384616	DF: 17.606799128464857
#
# Epoch:87/100 	Train Loss: 0.1032 	Valid Loss: 1.0427 -------- Train Accuracy: 96.58600637779028 	Valid Accuracy: 74.15384615384616	DF: 22.432160223944123
#
# Epoch:88/100 	Train Loss: 0.0873 	Valid Loss: 0.8038 -------- Train Accuracy: 97.07371975239167 	Valid Accuracy: 79.6923076923077	DF: 17.381412060083974
#
# Epoch:89/100 	Train Loss: 0.0875 	Valid Loss: 0.7706 -------- Train Accuracy: 97.14875257925343 	Valid Accuracy: 78.15384615384616	DF: 18.994906425407265
#
# Epoch:90/100 	Train Loss: 0.0997 	Valid Loss: 0.7419 -------- Train Accuracy: 96.71731382479835 	Valid Accuracy: 79.38461538461539	DF: 17.332698440182966
#
# Epoch:91/100 	Train Loss: 0.0853 	Valid Loss: 0.8512 -------- Train Accuracy: 97.1862689926843 	Valid Accuracy: 76.61538461538461	DF: 20.57088437729969
#
# Epoch:92/100 	Train Loss: 0.0852 	Valid Loss: 0.9152 -------- Train Accuracy: 97.1862689926843 	Valid Accuracy: 74.76923076923077	DF: 22.41703822345353
#
# Epoch:93/100 	Train Loss: 0.0983 	Valid Loss: 1.0691 -------- Train Accuracy: 96.47345713749766 	Valid Accuracy: 72.61538461538461	DF: 23.858072522113048
#
# Epoch:94/100 	Train Loss: 0.1114 	Valid Loss: 1.0896 -------- Train Accuracy: 96.21084224348152 	Valid Accuracy: 73.84615384615384	DF: 22.364688397327683
#
# Epoch:95/100 	Train Loss: 0.0849 	Valid Loss: 0.9422 -------- Train Accuracy: 97.24254361283062 	Valid Accuracy: 78.15384615384616	DF: 19.088697458984456
#
# Epoch:96/100 	Train Loss: 0.1078 	Valid Loss: 0.8321 -------- Train Accuracy: 96.26711686362783 	Valid Accuracy: 78.46153846153847	DF: 17.805578402089367
#
# Epoch:97/100 	Train Loss: 0.0997 	Valid Loss: 0.9708 -------- Train Accuracy: 96.84862127180642 	Valid Accuracy: 77.23076923076923	DF: 19.617852041037196
#
# Epoch:98/100 	Train Loss: 0.0837 	Valid Loss: 0.9128 -------- Train Accuracy: 97.41136747326955 	Valid Accuracy: 75.6923076923077	DF: 21.719059780961857
#
# Epoch:99/100 	Train Loss: 0.0816 	Valid Loss: 0.7821 -------- Train Accuracy: 97.22378540611517 	Valid Accuracy: 78.46153846153847	DF: 18.762246944576702
#
# Epoch:100/100 	Train Loss: 0.0729 	Valid Loss: 0.9899 -------- Train Accuracy: 97.67398236728569 	Valid Accuracy: 76.3076923076923	DF: 21.366290059593382

# %%
# Save history for later
train_loss_history = train_losses
valid_loss_history = valid_losses

# Plot training and validation curve
x = range(1, num_epochs + 1)
plt.plot(x, train_loss_history, label='train')
plt.plot(x, valid_loss_history, label='valid')

plt.xlabel('# epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
